# %% [markdown]
# <a href="https://colab.research.google.com/github/Ravurumadhuri/numpy-and-pandas/blob/main/numpy_and_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Numpy

# %%
import numpy as np

# %% [markdown]
# Array Creation Functions

# %%
a = np.array([1, 2, 3])
a
# Out:
# array([1, 2, 3])

# %%
b = np.zeros((2,3))
print(b)
# Out:
# [[0. 0. 0.]
#  [0. 0. 0.]]

# %%
c = np.ones((2,2))
print(c)
# Out:
# [[1. 1.]
#  [1. 1.]]

# %%
d = np.arange(1, 10, 2)
print(d)
# Out:
# [1 3 5 7 9]
